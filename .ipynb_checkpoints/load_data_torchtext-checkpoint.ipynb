# %%
use_cuda = True
batch_size = 2
learning_rate = 0.01

# %% [markdown]
# # Import library

# %%
from __future__ import print_function

import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torchtext

import numpy as np

import time
import math
import random
import unicodedata
import string
import re
from tqdm import tqdm

import scripts.text
import utils

# %% [markdown]
# # Load data

# %%
data_path = './processed-data/id.1000/'
en_vocab_path = data_path + 'train.10k.en.vocab'
de_vocab_path = data_path + 'train.10k.de.vocab'

# %%
en_words, en_vocab, _ = scripts.text.load_vocab(en_vocab_path)
de_words, de_vocab, _ = scripts.text.load_vocab(de_vocab_path)
# Out:
# # Loading vocab file ./processed-data/id.1000/train.10k.en.vocab ...
#   num words = 1000
# # Loading vocab file ./processed-data/id.1000/train.10k.de.vocab ...
#   num words = 1000

# %%
class LuongNMTDataset(torchtext.data.Dataset):
    """
        Custom Dataset for Machine Translation dataset based on torchtext's Dataset class.
    """
    
    def __init__(self, src_path, trg_path, fields, MAX_LENGTH=None, **kwargs):
        """
            Arguments:
                src_path (string): path to source language data.
                trg_path (string): path to target language data.
                fields: A tuple containing the fields that will be used for data in each language.
                Remaining keyword arguments: Passed to the constructor of data.Dataset.
        """
        
        if not isinstance(fields[0], (tuple, list)):
            fields = [('src', fields[0]), ('trg', fields[1])]
        
        examples = []
        with open(src_path) as src_file, open(trg_path) as trg_file:
            for src_line, trg_line in tqdm(zip(src_file, trg_file)):
                src_line, trg_line = src_line.split(' '), trg_line.split(' ')
                if MAX_LENGTH is not None:
                    if len(src_line) > MAX_LENGTH or len(trg_line) > MAX_LENGTH:
                        continue
                if src_line != '' and trg_line != '':
                    print(src_line)
                    examples.append(torchtext.data.Example.fromlist([src_line, trg_line], fields))
        
        super(LuongNMTDataset, self).__init__(examples, fields, **kwargs)

# %%
with open(data_path + 'train.10k.en') as f:
    for line in f:
        print(map(int, line.split()))
        break
# Out:
# [0, 0, 11, 9, 0, 13, 112, 0, 40, 11, 0, 21, 9, 0, 26, 0, 0, 25, 0, 10, 4, 0, 0, 22, 0, 24, 7, 4, 0, 0, 0, 5]

# %%
src_field = torchtext.data.Field(sequential=True,
                                 tokenize=(lambda line: line),
                                 use_vocab=False, 
                                 batch_first=True
                                 )
trg_field = torchtext.data.Field(sequential=True, 
                                 tokenize=(lambda line: line),
                                 use_vocab=False, 
                                 batch_first=True
                                 )

# %%
train_dataset = LuongNMTDataset(src_path=data_path + 'train.10k.en', 
                            trg_path=data_path + 'train.10k.de', 
                            fields=(src_field, trg_field)
                           )
# Out:
#  12%|█▏        | 1229/10000 [00:00<00:00, 12282.98it/s]
# ['0', '0', '11', '9', '0', '13', '112', '0', '40', '11', '0', '21', '9', '0', '26', '0', '0', '25', '0', '10', '4', '0', '0', '22', '0', '24', '7', '4', '0', '0', '0', '5\n']
# ['0', '0', '0', '4', '0', '452', '4', '0', '3', '0', '0', '0', '747', '5\n']
# ['9', '0', '0', '0', '0', '13', '0', '677', '3', '0', '3', '248', '0', '282', '5\n']
# ['0', '0', '0', '550', '0', '3', '0', '84', '0', '6', '0', '0', '6', '4', '0', '7', '0', '0', '25', '79', '670', '5\n']
# ['377', '9', '0', '7', '4', '605', '0', '0', '0', '8', '0', '968', '0', '5\n']
# ['0', '0', '6', '0', '945', '86', '10', '4', '923', '951', '100', '0', '0', '6', '49', '0', '8', '213', '3', '0', '645', '13', '374', '6', '394', '0', '5\n']
# ['0', '10', '0', '3', '4', '783', '7', '0', '172', '0', '10', '0', '47', '104', '0', '9', '314', '300', '7', '0', '277', '699', '622', '0', '0', '5\n']
# ['0', '19', '285', '0', '56', '66', '0', '730', '3', '577', '3', '0', '6', '0', '108', '3', '4', '58', '7', '0', '0', '212', '3', '0', '6', '0', '7', '0', '0', '5\n']
# ['48', '551', '11', '214', '20', '4', '0', '144', '260', '212', '22', '569', '3', '547', '3', '542', '212', '3', '260', '565', '3', '372', '187', '3', '282', '24', '516', '27', '339', '141', '12', '563', '254', '692', '0', '700', '5\n']
# ['825', '0', '0', '17', '483', '10', '4', '109', '552', '339', '460', '803', '21', '178', '26', '0', '109', '552', '339', '479', '5\n']
# ['0', '0', '0', '30', '0', '32', '0', '0', '46', '0', '0', '6', '0', '4', '0', '6', '0', '7', '32', '627', '5\n']
# ['48', '551', '11', '214', '20', '4', '0', '144', '260', '212', '22', '569', '3', '547', '3', '542', '212', '3', '260', '565', '3',
# <b>limit_output extension: Maximum message size of 15000 exceeded with 292145 characters</b>

# %%
train_loader = torchtext.data.BucketIterator(dataset=train_dataset, 
                                             batch_size=2, 
                                             repeat=False, 
                                             shuffle=True,
                                             sort_within_batch=True, 
                                             sort_key=lambda x: len(x.src)
                                            )

# %%
len(train_loader)
# Out:
# 5000

# %%
for batch in train_loader:
    pass
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-6cd40a1ef3c3> in <module>()
# ----> 1 for batch in train_loader:
#       2     pass
#
# /home/mcsquared/anaconda2/lib/python2.7/site-packages/torchtext/data/iterator.pyc in __iter__(self)
#     178                         minibatch.sort(key=self.sort_key, reverse=True)
#     179                 yield Batch(minibatch, self.dataset, self.device,
# --> 180                             self.train)
#     181             if not self.repeat:
#     182                 raise StopIteration
#
# /home/mcsquared/anaconda2/lib/python2.7/site-packages/torchtext/data/batch.pyc in __init__(self, data, dataset, device, train)
#      20                 if field is not None:
#      21                     batch = [x.__dict__[name] for x in data]
# ---> 22                     setattr(self, name, field.process(batch, device=device, train=train))
#      23
#      24     @classmethod
#
# /home/mcsquared/anaconda2/lib/python2.7/site-packages/torchtext/data/field.pyc in process(self, batch, device, train)
#     185         """
#     186         padded = self.pad(batch)
# --> 187         tensor = self.numericalize(padded, device=device, train=train)
#     188         return tensor
#     189
#
# /home/mcsquared/anaconda2/lib/python2.7/site-packages/torchtext/data/field.pyc in numericalize(self, arr, device, train)
#     307                 arr = self.postprocessing(arr, None, train)
#     308
# --> 309         arr = self.tensor_type(arr)
#     310         if self.sequential and not self.batch_first:
#     311             arr.t_()
#
# ValueError: too many dimensions 'str'
